# %% [markdown]
# <a href="https://colab.research.google.com/github/deepakaithal006/DL/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

from keras.preprocessing import sequence
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Dropout, Embedding, LSTM, Bidirectional
from keras.datasets import imdb

n_unique_words = 10000 # cut texts after this number of words
maxlen = 200
batch_size = 128

(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=n_unique_words)

x_train = pad_sequences(x_train, maxlen=maxlen)
x_test = pad_sequences(x_test, maxlen=maxlen)

y_train = np.array(y_train)
y_test = np.array(y_test)

model = Sequential()
model.add(Embedding(n_unique_words, 128, input_length=maxlen))
model.add(Bidirectional(LSTM(64)))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

history = model.fit(x_train, y_train, batch_size=batch_size, epochs=10,
                    validation_data=(x_test, y_test))

test_loss, test_acc = model.evaluate(x_test, y_test)

print('Test loss', test_loss)
print('Test accuracy', test_acc)

print(history.history['loss'])
print(history.history['accuracy'])

from matplotlib import pyplot

pyplot.plot(history.history['loss'])
pyplot.plot(history.history['accuracy'])

pyplot.title('model loss vs accuracy')
pyplot.xlabel('epoch')
pyplot.legend(['loss', 'accuracy'], loc='upper right')
pyplot.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Epoch 1/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 14s 32ms/step - accuracy: 0.7737 - loss: 0.4721 - val_accuracy: 0.8190 - val_loss: 0.4018
# Epoch 2/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 6s 33ms/step - accuracy: 0.8916 - loss: 0.2767 - val_accuracy: 0.8751 - val_loss: 0.3051
# Epoch 3/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - accuracy: 0.9261 - loss: 0.2002 - val_accuracy: 0.8746 - val_loss: 0.3060
# Epoch 4/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 6s 33ms/step - accuracy: 0.9361 - loss: 0.1723 - val_accuracy: 0.8622 - val_loss: 0.3605
# Epoch 5/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 6s 30ms/step - accuracy: 0.9526 - loss: 0.1328 - val_accuracy: 0.8656 - val_loss: 0.3592
# Epoch 6/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 6s 33ms/step - accuracy: 0.9622 - loss: 0.1062 - val_accuracy: 0.8352 - val_loss: 0.4857
# Epoch 7/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - accuracy: 0.9699 - loss: 0.0893 - val_accuracy: 0.8583 - val_loss: 0.4812
# Epoch 8/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 6s 33ms/step - accuracy: 0.9784 - loss: 0.0664 - val_accuracy: 0.8564 - val_loss: 0.4962
# Epoch 9/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 11s 36ms/step - accuracy: 0.9724 - loss: 0.0802 - val_accuracy: 0.8552 - val_loss: 0.5950
# Epoch 10/10
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 6s 33ms/step - accuracy: 0.9841 - loss: 0.0534 - val_accuracy: 0.8495 - val_loss: 0.5676
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.8495 - loss: 0.5676
# Test loss 0.5676017999649048
# Test accuracy 0.8494799733161926
# [0.4720548093318939, 0.27673134207725525, 0.20020274817943573, 0.17225705087184906, 0.13282045722007751, 0.10623883455991745, 0.08931948244571686, 0.06638247519731522, 0.08016253262758255, 0.05337804555892944]
# [0.7737200260162354, 0.8916000127792358, 0.9261199831962585, 0.9361199736595154, 0.9526000022888184, 0.9622399806976318, 0.9698799848556519, 0.9783599972724915, 0.9724000096321106, 0.9840800166130066]
